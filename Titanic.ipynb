# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
import seaborn as sns
sns.set(color_codes=True)

# %%
cd Downloads
# Out:
# /home/royal/Downloads

# %%
train2=pd.read_csv('train (2).csv')
test2=pd.read_csv('test (1).csv')

# %%
test.head()
passenger=test['PassengerId']
test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
# test.drop(['PassengerId','Name','SibSp','Parch','Fare','Cabin'],axis=1, inplace=True)
# test2.drop(['PassengerId','Ticket','SibSp','Parch','Fare','Cabin'],axis=1, inplace=True)

import re
te=[]
e=0
eo=[]
for i in test2['Name']:
    
    te.append(re.findall(r"\w+\.",i))
# Out:
# [['Mr.'],
#  ['Mrs.'],
#  ['Mr.'],
#  ['Mr.'],
#  ['Mrs.'],
#  ['Mr.'],
#  ['Miss.'],
#  ['Mr.'],
#  ['Mrs.'],
#  ['Mr.'],
#  ['Mr.'],
#  ['Mr.'],
#  ['Mrs.'],
#  ['Mr.'],
#  ['Mrs.'],
#  ['Mrs.'],
#  ['Mr.'],
#  ['Mr.'],
#  ['Miss.'],
#  ['Mrs.'],
#  ['Mr.'],
#  ['Master.'],
#  ['Mrs.'],
#  ['Mr.'],
#  ['Mrs.'],
#  ['Mr.'],
#  ['Miss.'],
#  ['Mr.'],
#  ['Mr.'],
#  ['Mr.'],
#  ['Mr.'],
#  ['Mr.'],
#  ['Mrs.'],
#  ['Mrs.'],
#  ['Mr.'],
#  ['Mr.'],
#  ['Miss.'],
#  ['Miss.'],
#  ['Mr.'],
#  ['Mr.'],
#  ['Mr.'],
#  ['Mr.'],
#  ['Mr.'],
#  ['Mrs.'],
#  ['Mrs.'],
#  ['Mr.'],
#  ['Mr.'],
#  ['Mr.'],
#  ['Mrs.'],
#  ['Mrs.'],
#  ['Mr.'],
#  ['Mr.'],
#  ['Miss.'],
#  ['Miss.'],
#  ['Mr.'],
#  ['Master.'],
#  ['Mr.'],
#  ['Mr.'],
#  ['Mr.'],
#  ['Miss.'],
#  ['Mr.'],
#  ['Mr.'],
#  ['Mr.'],
#  ['Miss.'],
#  ['Master.'],
#  ['Mrs.'],
#  ['Miss.'],
#  ['Mr.'],
#  ['Mr.'],
#  ['Mrs.'],
#  ['Miss.'],
#  ['Mr.'],
#  ['Miss.'],
#  ['Mr.'],
#  ['Miss.'],
#  ['Mr.'],
#  ['Mr.'],
#  ['Mrs.'],
# ...

# %%
# age_test=np.where(test2['Age'].isnull())
age_test=[10,  22,  29,  33,  36,  39,  41,  47,  54,  58,  65,  76,  83,
         84,  85,  88,  91,  93, 102, 107, 108, 111, 116, 121, 124, 127,
        132, 133, 146, 148, 151, 160, 163, 168, 170, 173, 183, 188, 191,
        199, 200, 205, 211, 216, 219, 225, 227, 233, 243, 244, 249, 255,
        256, 265, 266, 267, 268, 271, 273, 274, 282, 286, 288, 289, 290,
        292, 297, 301, 304, 312, 332, 339, 342, 344, 357, 358, 365, 366,
        380, 382, 384, 408, 410, 413, 416, 417]
len(age_test)
te[age_test[0]]
# Out:
# ['Mr.']

# %%
import random
from random import randint

new3=[]
for i in range(len(age_test)):
#     print(i[0])
    if 'Mr.' or 'Mrs.' in te[age_test[i]]:
        new3.append(random.randint(35,60))
                             
    elif 'Master.' or 'Miss.' in te[age_test[i]]:
        new3.append(random.randint(10,18))

    

len(new3)# new2_arr=np.array(new
# Out:
# 86

# %%
for i in range(len(new3)):
#     l=j.pop(0)
#     print('l',l)
#     print('el',el[i])
#     print(new)
    test['Age'][age_test.pop()]=new3[i]
# Out:
# /home/royal/.local/lib/python3.6/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys

# %%
# test['Sex']=np.where(test['Sex']=='male',1,0)
# test.drop(['Ticket'],axis=1, inplace=True)
test.head()
test.isnull().any()
# Out:
# Pclass      False
# Sex         False
# Age         False
# Embarked    False
# dtype: bool

# %%
test.head()
# Out:
#    Pclass  Sex   Age Embarked
# 0       3    1  34.5        Q
# 1       3    0  47.0        S
# 2       2    1  62.0        Q
# 3       3    1  27.0        S
# 4       3    0  22.0        S

# %%
train.drop(['Ticket','Cabin'],axis=1)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
train['Sex']=np.where(train['Sex']=='male',1,0)

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    1  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0      1      0
# 2                             Heikkinen, Miss. Laina    0  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0      1      0
# 4                           Allen, Mr. William Henry    1  35.0      0      0
#
#              Ticket     Fare Cabin Embarked
# 0         A/5 21171   7.2500   NaN        S
# 1          PC 17599  71.2833   C85        C
# 2  STON/O2. 3101282   7.9250   NaN        S
# 3            113803  53.1000  C123        S
# 4            373450   8.0500   NaN        S

# %%
train=train.drop(['Ticket'],axis=1)

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    1  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0      1      0
# 2                             Heikkinen, Miss. Laina    0  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0      1      0
# 4                           Allen, Mr. William Henry    1  35.0      0      0
#
#       Fare Cabin Embarked
# 0   7.2500   NaN        S
# 1  71.2833   C85        C
# 2   7.9250   NaN        S
# 3  53.1000  C123        S
# 4   8.0500   NaN        S

# %%
import re
ro=[]
c=0
bo=[]
for i in train['Name']:
    
    ro.append(re.findall(r"\w+\.",i))
    bo.append(c)
    c=c+1

ro
# Out:
# [['Mr.'],
#  ['Mrs.'],
#  ['Miss.'],
#  ['Mrs.'],
#  ['Mr.'],
#  ['Mr.'],
#  ['Mr.'],
#  ['Master.'],
#  ['Mrs.'],
#  ['Mrs.'],
#  ['Miss.'],
#  ['Miss.'],
#  ['Mr.'],
#  ['Mr.'],
#  ['Miss.'],
#  ['Mrs.'],
#  ['Master.'],
#  ['Mr.'],
#  ['Mrs.'],
#  ['Mrs.'],
#  ['Mr.'],
#  ['Mr.'],
#  ['Miss.'],
#  ['Mr.'],
#  ['Miss.'],
#  ['Mrs.'],
#  ['Mr.'],
#  ['Mr.'],
#  ['Miss.'],
#  ['Mr.'],
#  ['Don.'],
#  ['Mrs.'],
#  ['Miss.'],
#  ['Mr.'],
#  ['Mr.'],
#  ['Mr.'],
#  ['Mr.'],
#  ['Mr.'],
#  ['Miss.'],
#  ['Miss.'],
#  ['Mrs.'],
#  ['Mrs.'],
#  ['Mr.'],
#  ['Miss.'],
#  ['Miss.'],
#  ['Mr.'],
#  ['Mr.'],
#  ['Miss.'],
#  ['Mr.'],
#  ['Mrs.'],
#  ['Master.'],
#  ['Mr.'],
#  ['Mrs.'],
#  ['Mrs.'],
#  ['Mr.'],
#  ['Mr.'],
#  ['Miss.'],
#  ['Mr.'],
#  ['Miss.'],
#  ['Master.'],
#  ['Mr.'],
#  ['Miss.'],
#  ['Mr.'],
#  ['Master.'],
#  ['Mr.'],
#  ['Master.'],
#  ['Mrs.'],
#  ['Mr.'],
#  ['Miss.'],
#  ['Mr.'],
#  ['Mr.'],
#  ['Miss.'],
#  ['Mr.'],
#  ['Mr.'],
#  ['Mr.'],
#  ['Mr.'],
#  ['Mr.'],
# ...

# %%
ro[ne[7]
# Out:
# ['Master.']

# %%
age_v=np.where(train['Age'].isnull())
age_v
# Out:
# (array([  5,  17,  19,  26,  28,  29,  31,  32,  36,  42,  45,  46,  47,
#          48,  55,  64,  65,  76,  77,  82,  87,  95, 101, 107, 109, 121,
#         126, 128, 140, 154, 158, 159, 166, 168, 176, 180, 181, 185, 186,
#         196, 198, 201, 214, 223, 229, 235, 240, 241, 250, 256, 260, 264,
#         270, 274, 277, 284, 295, 298, 300, 301, 303, 304, 306, 324, 330,
#         334, 335, 347, 351, 354, 358, 359, 364, 367, 368, 375, 384, 388,
#         409, 410, 411, 413, 415, 420, 425, 428, 431, 444, 451, 454, 457,
#         459, 464, 466, 468, 470, 475, 481, 485, 490, 495, 497, 502, 507,
#         511, 517, 522, 524, 527, 531, 533, 538, 547, 552, 557, 560, 563,
#         564, 568, 573, 578, 584, 589, 593, 596, 598, 601, 602, 611, 612,
#         613, 629, 633, 639, 643, 648, 650, 653, 656, 667, 669, 674, 680,
#         692, 697, 709, 711, 718, 727, 732, 738, 739, 740, 760, 766, 768,
#         773, 776, 778, 783, 790, 792, 793, 815, 825, 826, 828, 832, 837,
# ...

# %%
train['PassengerId']         = train['PassengerId'].replace(5, 500)

# %%
age_arr=np.array(age_v)

# %%
age_arr=age_arr.reshape(-1,1)

# %%
import random
from random import randint

new2=[]
for i in range(len(new)):
#     print(i[0])
    if 'Mr.' or 'Mrs.' in ro[new[i][0]]:
        new2.append(random.randint(35,60))
    elif 'Master.' or 'Miss.' in ro[new[i][0]]:
        print('hhhhh')
#     new2.append(ro[new[i][0]])

    

# new2_arr=np.array(new2)
# Out:
# [array([5]),
#  array([17]),
#  array([19]),
#  array([26]),
#  array([28]),
#  array([29]),
#  array([31]),
#  array([32]),
#  array([36]),
#  array([42]),
#  array([45]),
#  array([46]),
#  array([47]),
#  array([48]),
#  array([55]),
#  array([64]),
#  array([65]),
#  array([76]),
#  array([77]),
#  array([82]),
#  array([87]),
#  array([95]),
#  array([101]),
#  array([107]),
#  array([109]),
#  array([121]),
#  array([126]),
#  array([128]),
#  array([140]),
#  array([154]),
#  array([158]),
#  array([159]),
#  array([166]),
#  array([168]),
#  array([176]),
#  array([180]),
#  array([181]),
#  array([185]),
#  array([186]),
#  array([196]),
#  array([198]),
#  array([201]),
#  array([214]),
#  array([223]),
#  array([229]),
#  array([235]),
#  array([240]),
#  array([241]),
#  array([250]),
#  array([256]),
#  array([260]),
#  array([264]),
#  array([270]),
#  array([274]),
#  array([277]),
#  array([284]),
#  array([295]),
#  array([298]),
#  array([300]),
#  array([301]),
# ...

# %%
new2
# Out:
# [54,
#  53,
#  43,
#  42,
#  46,
#  38,
#  46,
#  57,
#  47,
#  47,
#  40,
#  55,
#  35,
#  44,
#  49,
#  36,
#  57,
#  59,
#  56,
#  47,
#  35,
#  44,
#  52,
#  42,
#  53,
#  47,
#  41,
#  40,
#  57,
#  48,
#  38,
#  43,
#  58,
#  56,
#  54,
#  58,
#  41,
#  58,
#  35,
#  51,
#  54,
#  45,
#  44,
#  42,
#  56,
#  35,
#  43,
#  50,
#  35,
#  49,
#  58,
#  40,
#  53,
#  51,
#  45,
#  56,
#  36,
#  58,
#  35,
#  49,
#  51,
#  51,
#  39,
#  56,
#  51,
#  39,
#  54,
#  60,
#  50,
#  50,
#  44,
#  48,
#  42,
#  56,
#  45,
#  35,
#  35,
#  43,
#  40,
#  43,
#  59,
#  38,
#  35,
#  52,
#  46,
#  49,
#  45,
#  54,
#  55,
#  40,
#  54,
#  48,
#  57,
#  43,
#  49,
#  39,
#  55,
#  43,
#  58,
#  60,
#  40,
#  36,
#  60,
#  59,
#  41,
#  58,
#  46,
#  49,
#  40,
#  37,
#  53,
#  36,
#  60,
#  49,
#  59,
#  38,
#  59,
#  35,
#  57,
#  37,
#  49,
#  35,
#  59,
#  53,
#  54,
#  59,
#  58,
#  57,
#  37,
#  38,
#  52,
#  50,
#  50,
#  42,
#  37,
#  39,
#  49,
#  41,
#  45,
#  35,
#  50,
#  48,
# ...

# %%
a={'w':[np.NaN,5,7,8,9,10,np.NaN],'b':[np.NaN,5,7,8,9,10,np.NaN]}

# %%
aaaa=pd.DataFrame(a)

# %%
j=[5,17,  19,  26,  28,  29,  31,  32,  36,  42,  45,  46,  47,
         48,  55,  64,  65,  76,  77,  82,  87,  95, 101, 107, 109, 121,
        126, 128, 140, 154, 158, 159, 166, 168, 176, 180, 181, 185, 186,
        196, 198, 201, 214, 223, 229, 235, 240, 241, 250, 256, 260, 264,
        270, 274, 277, 284, 295, 298, 300, 301, 303, 304, 306, 324, 330,
        334, 335, 347, 351, 354, 358, 359, 364, 367, 368, 375, 384, 388,
        409, 410, 411, 413, 415, 420, 425, 428, 431, 444, 451, 454, 457,
        459, 464, 466, 468, 470, 475, 481, 485, 490, 495, 497, 502, 507,
        511, 517, 522, 524, 527, 531, 533, 538, 547, 552, 557, 560, 563,
        564, 568, 573, 578, 584, 589, 593, 596, 598, 601, 602, 611, 612,
        613, 629, 633, 639, 643, 648, 650, 653, 656, 667, 669, 674, 680,
        692, 697, 709, 711, 718, 727, 732, 738, 739, 740, 760, 766, 768,
        773, 776, 778, 783, 790, 792, 793, 815, 825, 826, 828, 832, 837,
        839, 846, 849, 859, 863, 868, 878, 888]
el=['b','c','d']
for i in range(len(new2)):
#     l=j.pop(0)
#     print('l',l)
#     print('el',el[i])
#     print(new)
    train['Age'][j.pop()]=new2[i]
# #     el.pop(0)
#     print('new',el[0])
# Out:
# /home/royal/.local/lib/python3.6/site-packages/ipykernel_launcher.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
train['Age'].isnull().any()
# Out:
# False

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4          500         0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    1  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0      1      0
# 2                             Heikkinen, Miss. Laina    0  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0      1      0
# 4                           Allen, Mr. William Henry    1  35.0      0      0
#
#       Fare Cabin Embarked
# 0   7.2500   NaN        S
# 1  71.2833   C85        C
# 2   7.9250   NaN        S
# 3  53.1000  C123        S
# 4   8.0500   NaN        S

# %%
train=train.drop(['Name','PassengerId','SibSp','Parch'],axis=1)

# %%
train.drop(['Cabin'],axis=1,inplace=True)

# %%
train.head()
# Out:
#    Survived  Pclass  Sex   Age     Fare Embarked
# 0         0       3    1  22.0   7.2500        S
# 1         1       1    0  38.0  71.2833        C
# 2         1       3    0  26.0   7.9250        S
# 3         1       1    0  35.0  53.1000        S
# 4         0       3    1  35.0   8.0500        S

# %%
test['Embarked']=train['Embarked'].replace('S',0)

# %%
test['Embarked']=train['Embarked'].replace('C',1)

# %%
test['Embarked']=train['Embarked'].replace('Q',2)

# %%
test.head()
# Out:
#    Pclass  Sex   Age  Embarked
# 0       3    1  34.5       0.0
# 1       3    0  47.0       1.0
# 2       2    1  62.0       0.0
# 3       3    1  27.0       0.0
# 4       3    0  22.0       0.0

# %%
train[['Fare', 'Survived']].groupby(['Fare'], as_index=False).mean().sort_values(by='Survived', ascending=False)
# Out:
#          Fare  Survived
# 247  512.3292       1.0
# 196   57.9792       1.0
# 89    13.8583       1.0
# 88    13.7917       1.0
# 86    13.4167       1.0
# 83    12.6500       1.0
# 81    12.4750       1.0
# 79    12.2875       1.0
# 194   56.9292       1.0
# 77    12.0000       1.0
# 195   57.0000       1.0
# 74    11.1333       1.0
# 197   59.4000       1.0
# 52     8.5167       1.0
# 201   63.3583       1.0
# 202   65.0000       1.0
# 68     9.8417       1.0
# 204   69.3000       1.0
# 207   71.2833       1.0
# 209   75.2500       1.0
# 210   76.2917       1.0
# 211   76.7292       1.0
# 213   77.9583       1.0
# 214   78.2667       1.0
# 90    13.8625       1.0
# 191   55.4417       1.0
# 190   55.0000       1.0
# 188   52.5542       1.0
# 142   26.3875       1.0
# 141   26.2875       1.0
# ..        ...       ...
# 158   31.2750       0.0
# 136   25.9250       0.0
# 156   30.6958       0.0
# 147   27.9000       0.0
# 148   28.5000       0.0
# 113   18.0000       0.0
# ...

# %%
g = sns.FacetGrid(train, col='Survived')
g.map(plt.hist, 'Fare', bins=30)

# %%
train.drop(['Fare'],axis=1,inplace=True)

# %%
X_train = train.drop("Survived", axis=1)
Y_train = train["Survived"]

# %%
from sklearn.ensemble import RandomForestClassifier,GradientBoostingClassifier

# %%
random_forest = GradientBoostingClassifier(n_estimators=1000,learning_rate=0.001)
random_forest.fit(X_train, Y_train)

# train.isnull().any()

# %%
# train.dropna(inplace=True)
test.head().isnull().any()
# Out:
# Pclass      False
# Sex         False
# Age         False
# Embarked    False
# dtype: bool

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-470-9582c9805387> in <module>()
# ----> 1 random_forest.predict(test)
#
# ~/.local/lib/python3.6/site-packages/sklearn/ensemble/forest.py in predict(self, X)
#     536             The predicted classes.
#     537         """
# --> 538         proba = self.predict_proba(X)
#     539
#     540         if self.n_outputs_ == 1:
#
# ~/.local/lib/python3.6/site-packages/sklearn/ensemble/forest.py in predict_proba(self, X)
#     576         check_is_fitted(self, 'estimators_')
#     577         # Check data
# --> 578         X = self._validate_X_predict(X)
#     579
#     580         # Assign chunk of trees to jobs
#
# ~/.local/lib/python3.6/site-packages/sklearn/ensemble/forest.py in _validate_X_predict(self, X)
#     355                                  "call `fit` before exploiting the model.")
#     356
# ...

# %%
test.fillna(-9999,inplace=True)

# %%
ytut=random_forest.predict(test)

# %%
ytut==ytlol
# Out:
# array([ True, False,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True, False,  True, False, False,  True,  True,
#         True, False,  True,  True, False,  True, False,  True, False,
#         True,  True,  True,  True,  True, False,  True,  True,  True,
#        False,  True,  True,  True,  True,  True,  True, False, False,
#         True,  True,  True, False,  True,  True,  True, False, False,
#         True,  True,  True,  True,  True, False,  True,  True,  True,
#         True, False, False,  True,  True,  True, False,  True,  True,
#         True,  True, False,  True,  True, False,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True, False,
#         True,  True, False,  True,  True,  True, False,  True,  True,
#         True, False,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True, False, False,  True, False,  True,  True,
# ...

# %%
submission = pd.DataFrame({
        "PassengerId": passenger,
        "Survived": ytut
    })

# %%
submission.to_csv('titani.csv', sep=',',index=False)

# %%
pwd
# Out:
# '/home/royal/Downloads'
